# %% [markdown]
# ### 3.1 How many seconds are in an hour?
# Multiply the number of seconds in a minute (60) by the number of minutes in an hour (also 60)

# %%
60 * 60
# Out:
# 3600

# %% [markdown]
# ### 3.2 Assign to a variable
# Assign the result from the previous task (seconds in an hour) to a variable called `seconds_per_hour`

# %%
seconds_per_hour = 60 * 60
seconds_per_hour
# Out:
# 3600

# %% [markdown]
# ### 3.3 Seconds in a day
# How many seconds are in a day? Use your `seconds_per_hour` variable

# %%
seconds_per_hour * 24
# Out:
# 86400

# %% [markdown]
# ### 3.4 Save seconds in a day
# Calculate seconds per day again, but this time save the result in a variable called `seconds_per_day`

# %%
seconds_per_day = seconds_per_hour * 24
seconds_per_day
# Out:
# 86400

# %% [markdown]
# ### 3.5 Floating-point division
# Divide `seconds_per_day` by `seconds_per_hour`. Use floating-point (`/`) division

# %%
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %% [markdown]
# ### 3.6 Integer division
# Divide `seconds_per_day` by `seconds_per_hour`, using integer (`//`) division.
# Did this number agree with the floating-point value from the previous question, aside from the final `.0`?

# %%
seconds_per_day // seconds_per_hour
# Out:
# 24

# %% [markdown]
# Yes, aside from the final .0, this value (24) is the same as the result of the floating-point value (24.0).
